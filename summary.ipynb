# %% [markdown]
# # Import Modul

# %%
import pandas as pd # v 1.1.5
import os
from Summary import Summary

# %% [markdown]
# # Summary

# %%
s = Summary(mode='local', start_date='2019', end_date='2023')

# %%
s.dfs_days['20190103']
# Out:
#              Remarks   Prev  Open         Date   High    Low  Close  Change  \
# Stock Code
# AALI        --S1K--1  11675     0  03 Jan 2019  12225  11700  12225     550
# ABBA        --U9---2     96     0  03 Jan 2019     98     95     96       0
# ABDA        --U8---2   6975     0  03 Jan 2019      0      0   6975       0
# ABMM        --U9---1   2270     0  03 Jan 2019      0      0   2270       0
# ACES        --S9K--1   1510     0  03 Jan 2019   1595   1510   1580      70
# ...              ...    ...   ...          ...    ...    ...    ...     ...
# YPAS        --U3---2    605     0  03 Jan 2019    605    525    525     -80
# YULE        --U8---2    206     0  03 Jan 2019    184    162    165     -41
# ZBRA        --U9---2     50     0  03 Jan 2019      0      0     50       0
# ZINC        --U2---2   1600     0  03 Jan 2019   1615   1600   1605       5
# ZONE        --U4---2    515     0  03 Jan 2019    525    505    525      10
#
# ...

# %%
s.monthly_df['201901']
# Out:
#              Remarks   Prev  Open         Date   High    Low  Close  Change  \
# Stock Code
# AALI        --S1K--1  11825     0  02 Jan 2019  11850  11575  11675    -150
# ABBA        --U9---2     96     0  02 Jan 2019    100     95     96       0
# ABDA        --U8---2   6975     0  02 Jan 2019      0      0   6975       0
# ABMM        --U9---1   2270     0  02 Jan 2019      0      0   2270       0
# ACES        --S9K--1   1490     0  02 Jan 2019   1515   1490   1510      20
# ...              ...    ...   ...          ...    ...    ...    ...     ...
# YPAS        --U3---2    600     0  31 Jan 2019    700    570    680      80
# YULE        --U8---2    196     0  31 Jan 2019    196    180    188      -8
# ZBRA        --U9---2     50     0  31 Jan 2019      0      0     50       0
# ZINC        --U2---2   1650     0  31 Jan 2019   1715   1650   1675      25
# ZONE        --U4---2    496     0  31 Jan 2019    500    492    498       2
#
# ...

# %%
s.summary
# Out:
# {}

# %%
s.get_summary()
# Out:
# 202402 dilewat
# 202401 dilewat
# 2024 dilewat

# %% [markdown]
# # Test Summary

# %%
#s.dfs_days

# %%
s.set_summary_dict()

# %%
s.summary_dict_to_csv()

# %%
s.monthly['202201']
